# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('csv/problem-7-5.csv')

# %% [markdown]
# <h3>Problem 7.5</h3>
# <p>Anda diberi data anime. Tentukan:</p>
#
# <ol>
#     <li>Banyaknya data</li>
#     <li>Data anime berjudul "Fullmetal Alchemist: Brotherhood"</li>
#     <li>Banyaknya anime dengan jumlah member lebih dari 40.000 dan kecil dari 80.000</li>
#     <li>Data anime bertipe OVA dengan jumlah member lebih dari 120.000</li>
#     <li>Data anime dengan rating terendah</li>
#     <li>Data 10 anime dengan rating tertinggi. Jika ada rating yang sama, urutkan dari member terbanyak</li>
#     <li>Tabel frekuensi banyaknya anime setiap jenis</li>
#     <li>Rata-rata jumlah episode anime bertipe TV dan bergenre Shounen</li>
#     <li>Rata-rata ratung anime bertipe Movie dengan jumlah member lebih dari 100.000</li>
#     <li>Standar deviasi jumlah member</li>
#     <li>Koefisien korelasi jumlah member dan rating</li>
# </ol>

# %%
# 1. Banyaknya data
len(df)
# Out:
# 9582

# %%
# 2. Data anime berjudul "Fullmetal Alchemist: Brotherhood"
df.loc[df['name'] == "Fullmetal Alchemist: Brotherhood"]
# Out:
#       anime_id                              name  \
# 3037      5114  Fullmetal Alchemist: Brotherhood
#
#                                                   genre type  episodes  \
# 3037  Action, Adventure, Drama, Fantasy, Magic, Mili...   TV        64
#
#       rating  members
# 3037    9.26   793665

# %%
# 3. Banyaknya anime dengan jumlah member lebih dari 40.000 dan kecil dari 80.000
len(df.loc[(df['members'] > 40000) & (df['members'] < 80000)])
# Out:
# 494

# %%
 # 4. Data anime bertipe OVE dengan jumlah member lebih dari 120.000
 df.loc[(df['type'] == 'OVA') & (df['members'] > 120000)]
# Out:
#       anime_id                                               name  \
# 20          44  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...
# 568        777                                  Hellsing Ultimate
# 3713      7059                           Black★Rock Shooter (OVA)
# 5566     15037  Corpse Party: Tortured Souls - Bougyakusareta ...
# 5823     16762                                 Mirai Nikki Redial
# 6143     18397                             Shingeki no Kyojin OVA
#
#                                                   genre type  episodes  \
# 20    Action, Drama, Historical, Martial Arts, Roman...  OVA         4
# 568   Action, Horror, Military, Seinen, Supernatural...  OVA        10
# 3713               Action, Drama, School, Slice of Life  OVA         1
# 5566                                    Horror, Mystery  OVA         4
# 5823       Action, Psychological, Shounen, Supernatural  OVA         1
# 6143       Action, Drama, Fantasy, Shounen, Super Power  OVA         3
#
#       rating  members
# 20      8.83   129307
# 568     8.59   297454
# 3713    7.24   130665
# 5566    7.12   126699
# 5823    7.71   135604
# 6143    7.88   121063

# %%
# 5. Data anime dengan rating terendah
df.loc[df['rating'] == df['rating'].min()]
# Out:
#       anime_id                                name                  genre  \
# 9577     34476  Platonic Chain: Ansatsu Jikkouchuu  Sci-Fi, Slice of Life
#
#          type  episodes  rating  members
# 9577  Special         1    1.67       51

# %%
# 6. Data 10 anime dengan rating tertinggi. Jika ada rating yang sama, urutkan dari member terbanyak
df.sort_values(['rating', 'members'], ascending=[False, False])[:10]
# Out:
#       anime_id                                               name  \
# 9423     33662            Taka no Tsume 8: Yoshida-kun no X-Files
# 6935     23005                                   Mogura no Motoro
# 8946     32281                                     Kimi no Na wa.
# 9418     33607                                       Kahei no Umi
# 3037      5114                   Fullmetal Alchemist: Brotherhood
# 7871     28977                                           Gintama°
# 7541     26313                    Yakusoku: Africa Mizu to Midori
# 4354      9253                                        Steins;Gate
# 4600      9969                                      Gintama&#039;
# 9186     32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
#
#                                                   genre   type  episodes  \
# 9423                                     Comedy, Parody  Movie         1
# 6935                                      Slice of Life  Movie         1
# 8946               Drama, Romance, School, Supernatural  Movie         1
# 9418                                         Historical  Movie         1
# 3037  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV        64
# 7871  Action, Comedy, Historical, Parody, Samurai, S...     TV        51
# 7541                                        Drama, Kids    OVA         1
# 4354                                   Sci-Fi, Thriller     TV        24
# 4600  Action, Comedy, Historical, Parody, Samurai, S...     TV        51
# 9186             Comedy, Drama, School, Shounen, Sports     TV        10
#
#       rating  members
# 9423   10.00       13
# 6935    9.50       62
# 8946    9.37   200630
# 9418    9.33       44
# 3037    9.26   793665
# 7871    9.25   114262
# 7541    9.25       53
# 4354    9.17   673572
# 4600    9.16   151266
# 9186    9.15    93351

# %%
# 7. Tabel frekuensi banyaknya anime tiap jenis.
df['type'].value_counts()
# Out:
# TV         3161
# Movie      2073
# OVA        1839
# Special    1469
# ONA         573
# Music       467
# Name: type, dtype: int64

# %%
# 8. Rata-rata jumlah anime episode bertipe TV dan bergenre Shounen
df.loc[(df['type'] == "TV") & df['genre'].str.contains('Shounen')]
# Out:
#       anime_id                                               name  \
# 4            8                             Beet the Vandel Buster
# 5           15                                       Eyeshield 21
# 6           17                         Hungry Heart: Wild Striker
# 9           20                                             Naruto
# 10          22                                   Prince of Tennis
# ...        ...                                                ...
# 9061     32648                                          Handa-kun
# 9126     32802            Cardfight!! Vanguard G: Stride Gate-hen
# 9186     32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 9310     33255                          Saiki Kusuo no Ψ-nan (TV)
# 9468     33811                                          Teekyuu 8
#
#                                                   genre type  episodes  \
# 4             Adventure, Fantasy, Shounen, Supernatural   TV        52
# 5                       Action, Comedy, Shounen, Sports   TV       145
# 6                Comedy, Shounen, Slice of Life, Sports   TV        52
# 9     Action, Comedy, Martial Arts, Shounen, Super P...   TV       220
# 10              Action, Comedy, School, Shounen, Sports   TV       178
# ...                                                 ...  ...       ...
# 9061                     Comedy, Shounen, Slice of Life   TV        12
# 9126                              Action, Game, Shounen   TV        24
# 9186             Comedy, Drama, School, Shounen, Sports   TV        10
# 9310              Comedy, School, Shounen, Supernatural   TV       120
# 9468                            Comedy, Shounen, Sports   TV        12
#
#       rating  members
# 4       7.06     9848
# 5       8.08    83648
# 6       7.74    13469
# 9       7.81   683297
# 10      8.04    87643
# ...      ...      ...
# 9061    7.46    69621
# 9126    7.14     2121
# 9186    9.15    93351
# 9310    8.29    47092
# 9468    6.76     3961
#
# [619 rows x 7 columns]

# %%
# 9. Rata-rata rating anime bertipe Movie dengan jumlah member lebih dari 100.000
df.loc[(df['type'] == 'Movie') & (df['members'] > 100000)]['rating'].mean()
# Out:
# 8.210408163265306

# %%
# 10. Standar deviasi jumlah member
df['members'].std()
# Out:
# 57055.998090349516

# %%
# 11. Koefisien korelasi jumlah member dan rating
df['members'].corr(df['rating'])
# Out:
# 0.38874055640003247
